# %%
howdy_planet = "Howdy Planet!"
print(howdy_planet)
# Out:
# Howdy Planet!

# %%
directions = ["North", "South", "East", "West"]

for direction in directions:
    print(direction)
# Out:
# North
# South
# East
# West
